# %%
"""Tgs3Dami.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1GdxAjLGHQcaxPNaXGqzXCAqvSzLGwpFz
"""
# Out:
# 'Tgs3Dami.ipynb\n\nAutomatically generated by Colaboratory.\n\nOriginal file is located at\n    https://colab.research.google.com/drive/1GdxAjLGHQcaxPNaXGqzXCAqvSzLGwpFz\n'

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score

# %%
df = pd.read_csv('Live_20210128.csv')
df
# Out:
#       status_id status_type status_published  num_reactions  num_comments  \
# 0             1       video   4/22/2018 6:00            529           512
# 1             2       photo  4/21/2018 22:45            150             0
# 2             3       video   4/21/2018 6:17            227           236
# 3             4       photo   4/21/2018 2:29            111             0
# 4             5       photo   4/18/2018 3:22            213             0
# ...         ...         ...              ...            ...           ...
# 7045       7046       photo   9/24/2016 2:58             89             0
# 7046       7047       photo  9/23/2016 11:19             16             0
# 7047       7048       photo  9/21/2016 23:03              2             0
# 7048       7049       photo   9/20/2016 0:43            351            12
# 7049       7050       photo  9/10/2016 10:30             17             0
#
#       num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  \
# 0            262        432         92         3          1         1
# 1              0        150          0         0          0         0
# 2             57        204         21         1          1         0
# 3              0        111          0         0          0         0
# 4              0        204          9         0          0         0
# ...          ...        ...        ...       ...        ...       ...
# 7045           0         89          0         0          0         0
# 7046           0         14          1         0          1         0
# 7047           0          1          1         0          0         0
# 7048          22        349          2         0          0         0
# 7049           0         17          0         0          0         0
#
#       num_angrys  Column1  Column2  Column3  Column4
# 0              0      NaN      NaN      NaN      NaN
# 1              0      NaN      NaN      NaN      NaN
# 2              0      NaN      NaN      NaN      NaN
# 3              0      NaN      NaN      NaN      NaN
# 4              0      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...
# 7045           0      NaN      NaN      NaN      NaN
# 7046           0      NaN      NaN      NaN      NaN
# 7047           0      NaN      NaN      NaN      NaN
# 7048           0      NaN      NaN      NaN      NaN
# 7049           0      NaN      NaN      NaN      NaN
#
# [7050 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.drop(['status_id', 'status_published', 'Column1', 'Column2', 'Column3', 'Column4'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
df['status_type'].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
df
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
# 7049       photo             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# 1             0         0          0         0           0
# 2            21         1          1         0           0
# 3             0         0          0         0           0
# 4             9         0          0         0           0
# ...         ...       ...        ...       ...         ...
# 7045          0         0          0         0           0
# 7046          1         0          1         0           0
# 7047          1         0          0         0           0
# 7048          2         0          0         0           0
# 7049          0         0          0         0           0
#
# [7050 rows x 10 columns]

# %%
X = df.drop(['status_type'], axis=1)
y = df['status_type']

# %%
le = LabelEncoder() 
le.fit_transform(y)
y = le.transform(y) # 0.Link 1.Photo 2.Status 3.Video

# %% [markdown]
# X['status_type'].unique()

# %%
kmeans2 = KMeans(n_clusters=2, random_state=0)

# %%
kmeans2.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
centeroid = kmeans2.cluster_centers_

# %%
all = pd.DataFrame(centeroid,columns=['num_reactions','num_comments','num_shares','num_likes','num_loves','num_wows','num_hahas','num_sads','num_angrys'])
T = pd.concat((X,all), axis=0)
T
# Out:
#       num_reactions  num_comments  num_shares   num_likes   num_loves  \
# 0        529.000000    512.000000  262.000000  432.000000   92.000000
# 1        150.000000      0.000000    0.000000  150.000000    0.000000
# 2        227.000000    236.000000   57.000000  204.000000   21.000000
# 3        111.000000      0.000000    0.000000  111.000000    0.000000
# 4        213.000000      0.000000    0.000000  204.000000    9.000000
# ...             ...           ...         ...         ...         ...
# 7047       2.000000      0.000000    0.000000    1.000000    1.000000
# 7048     351.000000     12.000000   22.000000  349.000000    2.000000
# 7049      17.000000      0.000000    0.000000   17.000000    0.000000
# 0        224.142278    122.109857   30.806195  211.227529   10.908380
# 1        522.886525   5234.418440  491.624113  402.007092  101.921986
#
#       num_wows  num_hahas  num_sads  num_angrys
# 0     3.000000   1.000000  1.000000    0.000000
# 1     0.000000   0.000000  0.000000    0.000000
# 2     1.000000   1.000000  0.000000    0.000000
# 3     0.000000   0.000000  0.000000    0.000000
# 4     0.000000   0.000000  0.000000    0.000000
# ...        ...        ...       ...         ...
# 7047  0.000000   0.000000  0.000000    0.000000
# 7048  0.000000   0.000000  0.000000    0.000000
# 7049  0.000000   0.000000  0.000000    0.000000
# 0     1.152989   0.556810  0.197424    0.096396
# 1     7.971631   7.539007  2.510638    0.936170
#
# [7052 rows x 9 columns]

# %%
kesimpulan = 1,len(X)/2+1
print('Jadi data Jumlah Nilai Terbanyak Terdapat pada baris',kesimpulan[0],'sampai',int(kesimpulan[1]))
# Out:
# Jadi data Jumlah Nilai Terbanyak Terdapat pada baris 1 sampai 3526

# %%
kmeans3 = KMeans(n_clusters=3, random_state=0)

# %%
kmeans3.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
centeroid = kmeans3.cluster_centers_

# %%
all = pd.DataFrame(centeroid,columns=['num_reactions','num_comments','num_shares','num_likes','num_loves','num_wows','num_hahas','num_sads','num_angrys'])
T = pd.concat((X,all), axis=0)
T
# Out:
#       num_reactions  num_comments  num_shares    num_likes  num_loves  \
# 0        529.000000    512.000000  262.000000   432.000000  92.000000
# 1        150.000000      0.000000    0.000000   150.000000   0.000000
# 2        227.000000    236.000000   57.000000   204.000000  21.000000
# 3        111.000000      0.000000    0.000000   111.000000   0.000000
# 4        213.000000      0.000000    0.000000   204.000000   9.000000
# ...             ...           ...         ...          ...        ...
# 7048     351.000000     12.000000   22.000000   349.000000   2.000000
# 7049      17.000000      0.000000    0.000000    17.000000   0.000000
# 0        113.000000    108.951003   24.790170   103.412350   8.335511
# 1        486.737226   5309.591241  480.408759   376.072993  95.072993
# 2       1713.152893    317.871901  117.700413  1652.260331  47.774793
#
#       num_wows  num_hahas  num_sads  num_angrys
# 0     3.000000   1.000000  1.000000    0.000000
# 1     0.000000   0.000000  0.000000    0.000000
# 2     1.000000   1.000000  0.000000    0.000000
# 3     0.000000   0.000000  0.000000    0.000000
# 4     0.000000   0.000000  0.000000    0.000000
# ...        ...        ...       ...         ...
# 7048  0.000000   0.000000  0.000000    0.000000
# 7049  0.000000   0.000000  0.000000    0.000000
# 0     0.578784   0.409706  0.182455    0.078239
# 1     4.802920   7.394161  2.518248    0.875912
# 2     9.733471   2.609504  0.413223    0.361570
#
# [7053 rows x 9 columns]

# %%
ahc2 = AgglomerativeClustering(n_clusters=5, linkage='ward')
ahc2.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
ahcl = pd.DataFrame(ahc2.labels_,columns=['Label AHC'])
T = pd.concat((X,ahcl), axis=1)
T
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0               529           512         262        432         92         3
# 1               150             0           0        150          0         0
# 2               227           236          57        204         21         1
# 3               111             0           0        111          0         0
# 4               213             0           0        204          9         0
# ...             ...           ...         ...        ...        ...       ...
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
#       num_hahas  num_sads  num_angrys  Label AHC
# 0             1         1           0          2
# 1             0         0           0          2
# 2             1         0           0          2
# 3             0         0           0          2
# 4             0         0           0          2
# ...         ...       ...         ...        ...
# 7045          0         0           0          2
# 7046          1         0           0          2
# 7047          0         0           0          2
# 7048          0         0           0          2
# 7049          0         0           0          2
#
# [7050 rows x 10 columns]

# %%
DBI = davies_bouldin_score(X, y)

# %%
print('Nilai DBI adalah:', DBI)
# Out:
# Nilai DBI adalah: 8.521555091843334

# %%
X = pd.DataFrame(df,columns=['num_reactions','num_comments','num_shares'])

# %%
kmeans5 = KMeans(n_clusters=5, random_state=0)

# %%
kmeans5.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
centeroid = kmeans5.cluster_centers_

# %%
all = pd.DataFrame(centeroid,columns=['num_reactions','num_comments','num_shares'])
T = pd.concat((X,all), axis=0)
T
# Out:
#     num_reactions  num_comments  num_shares
# 0      529.000000    512.000000  262.000000
# 1      150.000000      0.000000    0.000000
# 2      227.000000    236.000000   57.000000
# 3      111.000000      0.000000    0.000000
# 4      213.000000      0.000000    0.000000
# ..            ...           ...         ...
# 0     1776.891960     71.600503   20.547739
# 1      571.181818  12727.090909  577.090909
# 2      500.265882   1440.840000  328.143529
# 3      497.877358   4988.132075  461.764151
# 4      105.311293     44.536170   12.966448
#
# [7055 rows x 3 columns]

# %%
kesimpulan = len(X)/4+1,len(X)/3+1
print('Jadi data Jumlah Nilai Terbanyak Terdapat pada baris',int(kesimpulan[0]),'sampai',kesimpulan[1])
# Out:
# Jadi data Jumlah Nilai Terbanyak Terdapat pada baris 1763 sampai 2351.0

# %%
ahc = AgglomerativeClustering(n_clusters=5, linkage='ward')
ahc.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
ahcl = pd.DataFrame(ahc.labels_,columns=['Label AHC'])
T = pd.concat((X,ahcl), axis=1)
T
# Out:
#       num_reactions  num_comments  num_shares  Label AHC
# 0               529           512         262          1
# 1               150             0           0          2
# 2               227           236          57          2
# 3               111             0           0          2
# 4               213             0           0          2
# ...             ...           ...         ...        ...
# 7045             89             0           0          2
# 7046             16             0           0          2
# 7047              2             0           0          2
# 7048            351            12          22          2
# 7049             17             0           0          2
#
# [7050 rows x 4 columns]

# %%
DBI = davies_bouldin_score(X, y)

# %%
print('Nilai DBI adalah:', DBI)
# Out:
# Nilai DBI adalah: 8.069731720455724

# %%
X = pd.DataFrame(df,columns=['num_loves','num_angrys'])

# %%
kmeans6 = KMeans(n_clusters=6, random_state=0)

# %%
kmeans6.fit(X)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
centeroid = kmeans6.cluster_centers_

# %%
all = pd.DataFrame(centeroid,columns=['num_loves','num_angrys'])
T = pd.concat((X,all), axis=0)
T[7040:7056]
# Out:
#        num_loves  num_angrys
# 7040    3.000000    0.000000
# 7041    2.000000    0.000000
# 7042    0.000000    0.000000
# 7043    1.000000    0.000000
# 7044    0.000000    0.000000
# 7045    0.000000    0.000000
# 7046    1.000000    0.000000
# 7047    1.000000    0.000000
# 7048    2.000000    0.000000
# 7049    0.000000    0.000000
# 0       1.378085    0.039158
# 1     446.750000    2.750000
# 2     145.638655    1.058824
# 3      82.195122    0.445993
# 4     260.865385    2.173077
# 5      39.612450    0.299197

# %%
kesimpulan = len(X)/5+1,len(X)/4+1
print('Jadi data Jumlah Nilai Terbanyak Terdapat pada baris',int(kesimpulan[0]),'sampai',int(kesimpulan[1]))
# Out:
# Jadi data Jumlah Nilai Terbanyak Terdapat pada baris 1411 sampai 1763

# %%
ahc = AgglomerativeClustering().fit(X)

# %%
ahcl = pd.DataFrame(ahc.labels_,columns=['Label AHC'])
T = pd.concat((X,ahcl), axis=1)
T
# Out:
#       num_loves  num_angrys  Label AHC
# 0            92           0          0
# 1             0           0          1
# 2            21           0          1
# 3             0           0          1
# 4             9           0          1
# ...         ...         ...        ...
# 7045          0           0          1
# 7046          1           0          1
# 7047          1           0          1
# 7048          2           0          1
# 7049          0           0          1
#
# [7050 rows x 3 columns]

# %%
DBI = davies_bouldin_score(X, y)

# %%
print('Nilai DBI adalah:', DBI)
# Out:
# Nilai DBI adalah: 18.39185656228368
